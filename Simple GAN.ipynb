# %% [markdown]
# So how do we make a linear GAN?
# Should I be using squared error??

# %%
import autograd.numpy as np
import autograd

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
### The mnist data set
from fuel.datasets import MNIST
def get_data(datatype):
    mnist = MNIST((datatype,))
    state = mnist.open()
    im,_ = mnist.get_data(state=state, request=[i for i in range(int(mnist.num_examples/3))] )
    return im.reshape(im.shape[0],28*28)/255
data = get_data('train')
print(data.shape)
# Out:
# (20000, 784)

# %%
def sigmoid(z):
    return 1/(1+np.exp(-z))

def DataDiscrim(data,params):
    #pick some batch from the dataset
    return Dis(data,params)
    
def GenDiscrim(noise,params):
    ### Sample some noise
    #which noise distribution and why?
    return Dis(Gen(noise,params),params)
    
def Gen(z,params):
    return sigmoid(np.dot(z,params['G_W'])+params['G_b'])

def Dis(z,params):
    return sigmoid(np.dot(z,params['D_W'])+params['D_b'])

def EstimateLoss(params,data,noise): 
    return ( #CE 1 log(p)
            -np.mean(np.log(DataDiscrim(data,params))) + 
            #CE 0 log(p)
            -np.mean(np.log(1-GenDiscrim(noise,params))) )

dL = autograd.grad(EstimateLoss)

# %%
if __name__ == '__main__':
    ### hyperparams
    batch_size = 50
    m = 10
    input_length = 784
    D_shape = (input_length,1)
    G_shape = (m,784)
    
    params = {}
    init_val = 1/np.sqrt(input_length)
    params['D_W'] = init_val*np.random.standard_normal(D_shape)
    params['D_b'] = init_val*np.random.standard_normal((1,D_shape[-1]))
    params['G_W'] = init_val*np.random.standard_normal(G_shape)
    params['G_b'] = init_val*np.random.standard_normal((1,G_shape[-1]))
    
    x = data[np.random.choice([n for n in range(data.shape[0])],batch_size),:]
    y = np.random.standard_normal((batch_size,m)) 

    #CE(p,q) = plog(q). But if p = 0 then p =  log(p+1) = 0
    data_D = DataDiscrim(x,params)
    gen_D = GenDiscrim(y,params)
    print('Feed discriminator data - mean value = {}'.format(np.mean(data_D)))
    print('Feed generator noise and then discriminate - mean value = {}'.format(np.mean(1-gen_D)))
    print('Cross entropy of discriminated data - mean value = {}'.format(np.mean(np.log(data_D))))
    print('Cross entropy of generated discriminated noise - mean value = {}'.format(np.mean(np.log(1.0-gen_D))))
    print('Total cross entropy = {}'.format(EstimateLoss(params,x,y)))

    out_grads = dL(params,x,y)
    for key in out_grads:
        print('grad {} -> {}'.format(key,out_grads[key].shape))
# Out:
# Feed discriminator data - mean value = 0.4541805817038873
# Feed generator noise and then discriminate - mean value = 0.689664248994148
# Cross entropy of discriminated data - mean value = -0.8009003120651853
# Cross entropy of generated discriminated noise - mean value = -0.37158166996770026
# Total cross entropy = 1.1724819820328856
# grad G_W -> (10, 784)
# grad D_b -> (1, 1)
# grad G_b -> (1, 784)
# grad D_W -> (784, 1)

# %%
def plotter(x):
    plt.figure(figsize=(8,8))
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(x[i,:].reshape(28,28),cmap='Greys_r')
        
if __name__ == '__main__':
    plotter(Gen(y,params))

# %%
def train(params):
    #A simple two layer linear autoencoder
    N = 10000
    for i in range(N):
        ### SGD
        #stochastic batches
        x = data[np.random.choice([n for n in range(data.shape[0])],batch_size),:]
        y = np.random.standard_normal((batch_size,m)) 
        
        #grads
        param_grads = dL(params,x,y)
        
        #update params with steepest descent
        for key in param_grads:
            params[key] = params[key] - 0.0005*param_grads[key]  #update rule - follow the gradient downhill

        if i%(N/20) ==0:
            print('\r Loss = {}'.format(EstimateLoss(params,x,y)),end='')
    return params

trained_params = train(params)
# Out:
#  Loss = 0.029537243650646194

# %%
if __name__ == '__main__':
    plotter(Gen(y,trained_params))
